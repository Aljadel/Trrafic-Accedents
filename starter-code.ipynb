# %% [markdown]
# # Project 1: Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Problem Statment
#
# Craft your problem statement here using the prompt from the README and other sources you find during your investigation.

# %% [markdown]
# ## Executive Summary
# Write an executive summary that summarizes the problem and your key findings.

# %% [markdown]
# ### Contents:
# - [Datasets Description](#Datasets-Description)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here, including any Jupyter magic commands*

# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

#Setting display format to retina in matplotlib to see better quality images.
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Read In Driving Licenses & Traffic Accidents Data
# Read in the `saudi-arabia-traffic-accidents-2008.csv` and `saudi-arabia-driving-licenses-2004-2008.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code
df_1 = pd.read_csv('data/saudi-arabia-traffic-accidents-2008.csv', delimiter = ";") 
df_2 =  pd.read_csv ('data/saudi-arabia-driving-licenses-2004-2008.csv', delimiter = ";")

# %% [markdown]
# #### 2. Display data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code
df_1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year          Region  \
# 0           0             0  (2016)          Makkah
# 1           1             1  (2016)  Eastern Region
# 2           2             2  (2016)          Tabouk
# 3           3             3  (2016)            Hail
# 4           4             4  (2016)            Hail
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# 4             No. of Accidents  10199n   27.400845724, 41.4406960508

# %%
df_2.head()
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334

# %%
df_1 = df_1.drop(['Unnamed: 0','Unnamed: 0.1'], axis = 1);
df_2 = df_2.drop(['Unnamed: 0'], axis = 1)

# %%
df_1.tail()
# Out:
#       Year    Region                    Indicator  Value  \
# 79  (2017)      Asir  No. of Casualties - Injured  2368n
# 80  (2017)      Hail  No. of Casualties - Injured   773n
# 81  (2017)  Al-Baaha     No. of Casualties - Dead   134n
# 82  (2017)  Al-Baaha             No. of Accidents  1414n
# 83  (2017)  Al-Baaha  No. of Casualties - Injured  1007n
#
#                     geo_point_2d
# 79   19.1387847401, 42.941470036
# 80   27.400845724, 41.4406960508
# 81  20.1484058503, 41.4665484892
# 82  20.1484058503, 41.4665484892
# 83  20.1484058503, 41.4665484892

# %%
df_2.tail()
# Out:
#        Year Administritive Area Driving Liceses                 geo_point_2d
# 345  (2000)              Tabouk           8473n   27.90165499, 37.2598581394
# 346  (2006)              Tabouk           8259n   27.90165499, 37.2598581394
# 347  (2013)                Hail           9731n  27.400845724, 41.4406960508
# 348  (1997)                Hail           6606n  27.400845724, 41.4406960508
# 349  (1999)                Hail           3139n  27.400845724, 41.4406960508

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
# Year            84 non-null object
# Region          84 non-null object
# Indicator       84 non-null object
# Value           84 non-null object
# geo_point_2d    78 non-null object
# dtypes: object(5)
# memory usage: 3.4+ KB

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 4 columns):
# Year                   350 non-null object
# Administritive Area    350 non-null object
# Driving Liceses        350 non-null object
# geo_point_2d           325 non-null object
# dtypes: object(4)
# memory usage: 11.0+ KB

# %% [markdown]
# #### 3. Briefly describe the data
#
# Take your time looking through the data and briefly describe the data in the markdown cell below. Note things about what the columns might mean, and the general information that is conveyed in the dataframe.

# %% [markdown]
# Answer:

# %% [markdown]
# #### 4a. How complete is the data?
#
# Investigate missing values etc.

# %%
#Code
df_1.isnull().sum()
# Out:
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64

# %%
df_2.isnull().sum()
# Out:
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each dataset? What is the maximum *possible* value?**

# %%
#Code
df_1.describe()
# Out:
#           Year Region                    Indicator    Value  \
# count       84     84                           84       84
# unique       2     14                            3       84
# top     (2016)  Total  No. of Casualties - Injured  460488n
# freq        42      6                           28        1
#
#                        geo_point_2d
# count                            78
# unique                           13
# top     21.628962766, 41.2636898334
# freq                              6

# %%
df_2.describe()
# Out:
#           Year Administritive Area Driving Liceses  \
# count      350                 350             350
# unique      25                  14             350
# top     (1993)           Al-Qaseem         110295n
# freq        14                  25               1
#
#                        geo_point_2d
# count                           325
# unique                           13
# top     21.628962766, 41.2636898334
# freq                             25

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
df_1.dtypes
# Out:
# Year            object
# Region          object
# Indicator       object
# Value           object
# geo_point_2d    object
# dtype: object

# %%
df_2.dtypes
# Out:
# Year                   object
# Administritive Area    object
# Driving Liceses        object
# geo_point_2d           object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 6. Fix incorrect data types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert numerical columns to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
df_1['Value'] = df_1.Value.apply(lambda x : x.replace('n', ''))
df_1.head(2)
# Out:
#      Year          Region                    Indicator  Value  \
# 0  (2016)          Makkah  No. of Casualties - Injured  12383
# 1  (2016)  Eastern Region     No. of Casualties - Dead   1113
#
#                    geo_point_2d
# 0   21.628962766, 41.2636898334
# 1  23.2883307307, 50.1478302439

# %%
df_1['Value'] = pd.to_numeric(df_1.Value)
df_1.Value.dtype
# Out:
# dtype('int64')

# %%
df_2['Driving Liceses'] = df_2['Driving Liceses'].apply(lambda x : x.replace('n', ''))
df_2.head(2)
# Out:
#      Year Administritive Area Driving Liceses                 geo_point_2d
# 0  (2012)              Makkah          143954  21.628962766, 41.2636898334
# 1  (1994)              Makkah           75349  21.628962766, 41.2636898334

# %%
df_2['Driving Liceses'] = pd.to_numeric(df_2['Driving Liceses'])
df_2['Driving Liceses'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# - Make new columns `x` and `y` using `geo_point_2d`

# %%
#code
df_1['x'] = df_1['geo_point_2d'].apply(lambda x : str(x).split(',')[0])
df_1['y'] = df_1['geo_point_2d'].apply(lambda x : str(x).split(',')[-1])
df_1.head(2)
# Out:
#      Year          Region                    Indicator  Value  \
# 0  (2016)          Makkah  No. of Casualties - Injured  12383
# 1  (2016)  Eastern Region     No. of Casualties - Dead   1113
#
#                    geo_point_2d              x               y
# 0   21.628962766, 41.2636898334   21.628962766   41.2636898334
# 1  23.2883307307, 50.1478302439  23.2883307307   50.1478302439

# %%
df_2['x'] = df_1['geo_point_2d'].apply(lambda x : str(x).split(',')[0])
df_2['y'] = df_1['geo_point_2d'].apply(lambda x : str(x).split(',')[-1])
df_2.head(2)
# Out:
#      Year Administritive Area  Driving Liceses                 geo_point_2d  \
# 0  (2012)              Makkah           143954  21.628962766, 41.2636898334
# 1  (1994)              Makkah            75349  21.628962766, 41.2636898334
#
#                x               y
# 0   21.628962766   41.2636898334
# 1  23.2883307307   50.1478302439

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
df_1.dtypes
# Out:
# Year            object
# Region          object
# Indicator       object
# Value            int64
# geo_point_2d    object
# x               object
# y               object
# dtype: object

# %%
df_2.dtypes
# Out:
# Year                   object
# Administritive Area    object
# Driving Liceses         int64
# geo_point_2d           object
# x                      object
# y                      object
# dtype: object

# %%
df_1['Year'] = df_1.Year.apply(lambda x : x.replace('(', ''))
df_1['Year'] = df_1.Year.apply(lambda x : x.replace(')', ''))
df_1.head(2)
# Out:
#    Year          Region                    Indicator  Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
#
#                    geo_point_2d              x               y
# 0   21.628962766, 41.2636898334   21.628962766   41.2636898334
# 1  23.2883307307, 50.1478302439  23.2883307307   50.1478302439

# %%
df_1['Year'] = pd.to_numeric(df_1['Year'])
df_1['Year'].dtype
# Out:
# dtype('int64')

# %%
df_2['Year'] = df_2.Year.apply(lambda x : x.replace('(', ''))
df_2['Year'] = df_2.Year.apply(lambda x : x.replace(')', ''))
df_2.head(2)
# Out:
#    Year Administritive Area  Driving Liceses                 geo_point_2d  \
# 0  2012              Makkah           143954  21.628962766, 41.2636898334
# 1  1994              Makkah            75349  21.628962766, 41.2636898334
#
#                x               y
# 0   21.628962766   41.2636898334
# 1  23.2883307307   50.1478302439

# %%
df_2['Year'] = pd.to_numeric(df_2['Year'])
df_2['Year'].dtype
# Out:
# dtype('int64')

# %%
df_1['x'] = df_1['x'].astype(float)
df_1['y'] = df_1['y'].astype(float)
df_2['x'] = df_2['x'].astype(float)
df_2['y'] = df_2['y'].astype(float)
df_1['x'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
df_1.dtypes
# Out:
# Year              int64
# Region           object
# Indicator        object
# Value             int64
# geo_point_2d     object
# x               float64
# y               float64
# dtype: object

# %%
df_2.dtypes
# Out:
# Year                     int64
# Administritive Area     object
# Driving Liceses          int64
# geo_point_2d            object
# x                      float64
# y                      float64
# dtype: object

# %% [markdown]
# #### 7. Rename columns
# Change the names of the columns to more expressive names so that you can tell the difference the Driving Licenses  columns and the & Traffic Accidents columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these two datasets, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
# - Please also fix any typos you see in the column names.

# %%
#code
df_1.columns
# Out:
# Index(['Year', 'Region', 'Indicator', 'Value', 'geo_point_2d', 'x', 'y'], dtype='object')

# %%
df_2.columns
# Out:
# Index(['Year', 'Administritive Area', 'Driving Liceses', 'geo_point_2d', 'x',
#        'y'],
#       dtype='object')

# %%
df_1.rename(columns= { 
    'Year':'year', 
    'Region': 'region', 
    'Indicator': 'indicator', 
    'Value': 'value',
    'geo_point_2d':'geo', 
    'x':'x', 
    'y':'y',
}, inplace = True)
df_1.head()
# Out:
#    year          region                    indicator  value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#                             geo          x          y
# 0   21.628962766, 41.2636898334  21.628963  41.263690
# 1  23.2883307307, 50.1478302439  23.288331  50.147830
# 2    27.90165499, 37.2598581394  27.901655  37.259858
# 3   27.400845724, 41.4406960508  27.400846  41.440696
# 4   27.400845724, 41.4406960508  27.400846  41.440696

# %%
df_2.rename(columns= {
    'Year':'year',
    'Administritive Area':'region',
    'Driving Liceses':'driving_liceses',
    'geo_point_2d':'geo', 
    'x':'x', 
    'y':'y',
}, inplace = True)
df_2.head()
# Out:
#    year  region  driving_liceses                          geo          x  \
# 0  2012  Makkah           143954  21.628962766, 41.2636898334  21.628963
# 1  1994  Makkah            75349  21.628962766, 41.2636898334  23.288331
# 2  1998  Makkah            86082  21.628962766, 41.2636898334  27.901655
# 3  2004  Makkah            86636  21.628962766, 41.2636898334  27.400846
# 4  2005  Makkah            65099  21.628962766, 41.2636898334  27.400846
#
#            y
# 0  41.263690
# 1  50.147830
# 2  37.259858
# 3  41.440696
# 4  41.440696

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|Driving_Licenses/Traffic_Accidents|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |year|integr|df_1Traffic_Accidents & df_2Driving_Licenses|It is a year when driver's liceses were issued and Accidents were happened|
# |region|string|df_1Traffic_Accidents & df_2Driving_Licenses|It is a region where driving licenses were issued and Accidents were happened|
# |driving_licenses|intger|df_2Driving_Licenses|Number of driving licenses issued per region per year|
# |indicator|string| df_1Traffic_Accidents | Describe incidents |
# |value|integr| df_1Traffic_Accidents | Number of injuries, deaths and accidents |
# |  geo_point_2d  | string | df_1Traffic_Accidents & df_2Driving_Licenses |Region location coordinates |
# |x| float | df_1Traffic_Accidents & df_2Driving_Licenses | x coordinates for region |
# |y| float | df_1Traffic_Accidents & df_2Driving_Licenses | y coordinates for region |

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# This study concerns accident and license in regions/area. Please do the followings:
# 0. Which rows are not associated with regions?
# 1. Confirm the numbers of all regions add up to total.
# 2. Remove the rows that are not associated with regions

# %%
df_1.region.unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Total', 'Al-Baaha', 'Riyadh', 'Madinah',
#        'Qassim', 'Najran', 'Asir'], dtype=object)

# %%
df_2.region.unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern', 'Assir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Total', 'Riyadh'], dtype=object)

# %%
#total is not related to region, so drope it.
df_1 = df_1[~df_1.region.str.contains('Total')]
df_2 = df_2[~df_2.region.str.contains('Total')]
df_1.region.unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Al-Baaha', 'Riyadh', 'Madinah', 'Qassim',
#        'Najran', 'Asir'], dtype=object)

# %%
df_2.region.unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern', 'Assir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Riyadh'], dtype=object)

# %%
#code
#adjust splling of some regions
df_1['region'] = df_1.region.replace('Eastern Region','Eastern')
df_1['region'] = df_1.region.replace('Al-Baaha','Al-Baha')
df_1['region'] = df_1.region.replace('Qassim','Al-Qaseem')
df_1['region'] = df_1.region.replace('Asir','Assir')

# %%
df_1.region.unique()
# Out:
# array(['Makkah', 'Eastern', 'Tabouk', 'Hail', 'Northern Boarder', 'Jazan',
#        'Al-Jouf', 'Al-Baha', 'Riyadh', 'Madinah', 'Al-Qaseem', 'Najran',
#        'Assir'], dtype=object)

# %% [markdown]
# #### 10a. Data formats
# Is the License data in long or wide format? How about the Accident data? And why?

# %%
#code

# %% [markdown]
# #### 10b. Changing formats
# Which format would work best for both dataframes? Transform the datasets to the same format before merging in the next task.

# %%
#code
df_1 = df_1.pivot_table(index = ['year','region'], columns = 'indicator', values = 'value')
df_1
# Out:
# indicator              No. of Accidents  No. of Casualties - Dead  \
# year region
# 2016 Al-Baha                       3618                       185
#      Al-Jouf                      10212                       245
#      Al-Qaseem                    25664                       397
#      Assir                        32684                       983
#      Eastern                     101619                      1113
#      Hail                         10199                       299
#      Jazan                        25873                       514
#      Madinah                      14475                       822
#      Makkah                      134838                      2243
#      Najran                        3235                       173
#      Northern Boarder             13196                       193
#      Riyadh                      141736                      1430
#      Tabouk                       16031                       434
# ...

# %% [markdown]
# #### 11. Merge dataframes
#
# Join the Driving Licenses & Traffic Accidents dataframes using the **region** and **year** in each dataframe as the key. Assign this to a new variable. Which join should you use to preserve the most data?

# %%
#code
#join = pd.merge(r, w, how = 'left', on ['region','year'])
df = pd.merge(df_1, df_2, how = 'outer', on = ['region','year'])
df.head(5)
# Out:
#       region  year  No. of Accidents  No. of Casualties - Dead  \
# 0    Al-Baha  2016            3618.0                     185.0
# 1    Al-Jouf  2016           10212.0                     245.0
# 2  Al-Qaseem  2016           25664.0                     397.0
# 3      Assir  2016           32684.0                     983.0
# 4    Eastern  2016          101619.0                    1113.0
#
#    No. of Casualties - Injured  driving_liceses                           geo  \
# 0                       1227.0             4614  20.1484058503, 41.4665484892
# 1                        920.0             9371  29.9677445762, 39.5570371172
# 2                       1513.0             9180  26.1967063704, 43.3429998455
# 3                       2541.0            41367   19.1387847401, 42.941470036
# 4                       4893.0           142307  23.2883307307, 50.1478302439
#
#            x          y
# 0  27.400846  41.440696
# 1        NaN        NaN
# 2        NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 0 to 324
# Data columns (total 9 columns):
# region                         325 non-null object
# year                           325 non-null int64
# No. of Accidents               26 non-null float64
# No. of Casualties - Dead       26 non-null float64
# No. of Casualties - Injured    26 non-null float64
# driving_liceses                325 non-null int64
# geo                            325 non-null object
# x                              72 non-null float64
# y                              72 non-null float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 25.4+ KB

# %% [markdown]
# #### 12. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_datasets.csv`.

# %%
#code
df.to_csv('file2.csv', header=False, index=False)

# %%
df.head(2)
# Out:
#     region  year  No. of Accidents  No. of Casualties - Dead  \
# 0  Al-Baha  2016            3618.0                     185.0
# 1  Al-Jouf  2016           10212.0                     245.0
#
#    No. of Casualties - Injured  driving_liceses                           geo  \
# 0                       1227.0             4614  20.1484058503, 41.4665484892
# 1                        920.0             9371  29.9677445762, 39.5570371172
#
#            x          y
# 0  27.400846  41.440696
# 1        NaN        NaN

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
df.describe()
# Out:
#               year  No. of Accidents  No. of Casualties - Dead  \
# count   325.000000         26.000000                 26.000000
# mean   2005.000000      38225.692308                635.384615
# std       7.222222      46493.705035                549.783381
# min    1993.000000       1414.000000                112.000000
# 25%    1999.000000      10276.250000                241.250000
# 50%    2005.000000      16050.500000                415.500000
# 75%    2011.000000      30981.250000                929.250000
# max    2017.000000     145541.000000               2243.000000
#
#        No. of Casualties - Injured  driving_liceses          x          y
# count                    26.000000       325.000000  72.000000  72.000000
# mean                   2743.038462     28915.347692  23.846485  42.481893
# std                    2922.641127     47419.058819   4.195823   3.220614
# min                     374.000000       915.000000  17.207231  37.259858
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
#numpy
#sd = np.std(df)
#sd
#pandas
#std = df.std()
#std
def stav(l):#l=xlist
    new_list=[] #create empty list to save the thing which i will calaulat (stander deviation)
    mean=sum(l)/len(l) #mean of my list
    for i in l: #for each item(number) in my list calculate..
        num=i-mean #x-m 
        new_list.append(num*num)#(x-m)** #num**2
    #print(new_list)
    var = sum(new_list)/len(new_list)
    stdver= var**(1/2)
    return stdver
    
    
p=[1,2,3,4,5]
stav(p)
# Out:
# 1.4142135623730951

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'Driving_Licenses_x': 120, 'Traffic_Accidents_x': 120, ...}`

# %%
#Code:
{'Year':stav(list(df['year'])),
'Number of Accidents': stav(df['No. of Accidents'].notnull()),
'Number of Casualties Dead':stav(df['No. of Casualties - Dead'].notnull()),
'Number of Casualties Injured':stav(df['No. of Casualties - Injured'].notnull()),
'Driving Liceses':stav(list(df['driving_liceses']))}
# Out:
# {'Year': 7.211102550927978,
#  'Number of Accidents': 0.27129319932500945,
#  'Number of Casualties Dead': 0.27129319932500945,
#  'Number of Casualties Injured': 0.27129319932500945,
#  'Driving Liceses': 47346.05021744638}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
sd = np.std(df)
sd
# Out:
# year                               7.211103
# No. of Accidents               45590.828699
# No. of Casualties - Dead         539.106959
# No. of Casualties - Injured     2865.885411
# driving_liceses                47346.050217
# x                                  4.166583
# y                                  3.198170
# dtype: float64

# %%
#pandas
std = df.std()
std
# Out:
# year                               7.222222
# No. of Accidents               46493.705035
# No. of Casualties - Dead         549.783381
# No. of Casualties - Injured     2922.641127
# driving_liceses                47419.058819
# x                                  4.195823
# y                                  3.220614
# dtype: float64

# %%
df.describe()
# Out:
#               year  No. of Accidents  No. of Casualties - Dead  \
# count   325.000000         26.000000                 26.000000
# mean   2005.000000      38225.692308                635.384615
# std       7.222222      46493.705035                549.783381
# min    1993.000000       1414.000000                112.000000
# 25%    1999.000000      10276.250000                241.250000
# 50%    2005.000000      16050.500000                415.500000
# 75%    2011.000000      30981.250000                929.250000
# max    2017.000000     145541.000000               2243.000000
#
#        No. of Casualties - Injured  driving_liceses          x          y
# count                    26.000000       325.000000  72.000000  72.000000
# mean                   2743.038462     28915.347692  23.846485  42.481893
# std                    2922.641127     47419.058819   4.195823   3.220614
# min                     374.000000       915.000000  17.207231  37.259858
# ...

# %% [markdown]
# Answer: Yes, I manually calculated standard deviations.
# Some values are matching up with the output of pandas describe.
# Numpy's std method output are matching up with the output from pandas

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# - Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
# - What are the regions that have more Driving Licenses issued in each year than the year average?
# - What are the regions that have more Traffic Accidents happened in each year than the year average?
#
# Based on what you've just observed, have you identified any regions that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code
#Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
mask1 = df.mask((1992 < df['year'])&(df['year'] > 2018))
mask1.head(2)
# Out:
#     region  year  No. of Accidents  No. of Casualties - Dead  \
# 0  Al-Baha  2016            3618.0                     185.0
# 1  Al-Jouf  2016           10212.0                     245.0
#
#    No. of Casualties - Injured  driving_liceses                           geo  \
# 0                       1227.0             4614  20.1484058503, 41.4665484892
# 1                        920.0             9371  29.9677445762, 39.5570371172
#
#            x          y
# 0  27.400846  41.440696
# 1        NaN        NaN

# %%
highest_reg = mask1.loc[mask1['driving_liceses'] == 495307.000000, 'region'].iloc[0]
lowest_reg = mask1.loc[mask1['driving_liceses'] == 915.000000, 'region'].iloc[0]

print(f'Highest Driving Licenses are in {highest_reg} Region & Lowest Driving Licenses are in {lowest_reg} Region')

mask1.describe()                    
mask1.min()
# Out:
# Highest Driving Licenses are in Riyadh Region & Lowest Driving Licenses are in Tabouk Region
# region                                              Al-Baha
# year                                                   1993
# No. of Accidents                                       1414
# No. of Casualties - Dead                                112
# No. of Casualties - Injured                             374
# driving_liceses                                         915
# geo                            17.2072313962, 42.6525807422
# x                                                   17.2072
# y                                                   37.2599
# dtype: object

# %%
#Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
mask2 = df.mask((2015 < df['year'])&(df['year'] > 2018))
mask2.head(2)
# Out:
#     region  year  No. of Accidents  No. of Casualties - Dead  \
# 0  Al-Baha  2016            3618.0                     185.0
# 1  Al-Jouf  2016           10212.0                     245.0
#
#    No. of Casualties - Injured  driving_liceses                           geo  \
# 0                       1227.0             4614  20.1484058503, 41.4665484892
# 1                        920.0             9371  29.9677445762, 39.5570371172
#
#            x          y
# 0  27.400846  41.440696
# 1        NaN        NaN

# %%
highest_reg2 = mask2.loc[mask2['No. of Accidents'] == 145541.000000, 'region'].iloc[0]
lowest_reg2 = mask2.loc[mask2['No. of Accidents'] == 1414.000000, 'region'].iloc[0]

print(f'Highest Number of Accidents are in {highest_reg2} Region & Lowest Number of Accidents are in {lowest_reg2} Region')


mask2.describe()                    
mask2.min()
# Out:
# Highest Number of Accidents are in Makkah Region & Lowest Number of Accidents are in Al-Baha Region
# region                                              Al-Baha
# year                                                   1993
# No. of Accidents                                       1414
# No. of Casualties - Dead                                112
# No. of Casualties - Injured                             374
# driving_liceses                                         915
# geo                            17.2072313962, 42.6525807422
# x                                                   17.2072
# y                                                   37.2599
# dtype: object

# %%
#What are the regions that have more Driving Licenses issued in each year than the year average?
datafdl = pd.DataFrame()
datafdl['sum'] = df.groupby(['year', 'region'])['driving_liceses'].sum()
datafdl.reset_index(inplace = True)
datafdl.head(4)
# Out:
#    year     region    sum
# 0  1993    Al-Baha   3270
# 1  1993    Al-Jouf   2884
# 2  1993  Al-Qaseem  73618
# 3  1993      Assir   6226

# %%
datafdl1 = pd.DataFrame()
datafdl1['mean'] = df.groupby('year')['driving_liceses'].mean()
datafdl1.reset_index(inplace = True)
datafdl1.head(4)
# Out:
#    year          mean
# 0  1993  22684.076923
# 1  1994  23347.692308
# 2  1995  19375.230769
# 3  1996  18278.692308

# %%
datafdl2 = pd.merge(datafdl,datafdl1, how='left', on= 'year')
datafdl2.reset_index(inplace = True)
datafdl2.head(4)


datafdl3 = datafdl2.mask(datafdl2['sum']<datafdl2['mean']).groupby(['year', 'region'])['sum'].count()
final = pd.DataFrame(datafdl3)
final.reset_index(inplace = True)
#datafdl3

# %%
df33 = pd.DataFrame()
df33['sum'] = df.groupby(['year', 'region'])['No. of Accidents'].sum()
df33.reset_index(inplace = True)
#print(df33)

df4 = pd.DataFrame()
df4['mean'] = df.groupby('year')['No. of Accidents'].mean()
df4.reset_index(inplace = True)
#print(df4)


df5 = pd.merge(df33,df4, how='left', on= 'year')
df5.reset_index(inplace = True)

df6 = df5.mask((df5['year']<2016)|(df5['sum']<df5['mean'])).groupby(['year', 'region'])['sum'].count()
final = pd.DataFrame(df6)
final.reset_index(inplace = True)
final
# Out:
#      year   region  sum
# 0  2016.0  Eastern    1
# 1  2016.0   Makkah    1
# 2  2016.0   Riyadh    1
# 3  2017.0  Eastern    1
# 4  2017.0   Makkah    1
# 5  2017.0   Riyadh    1

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.bbb
#
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.gca()
sns.heatmap(df.corr(), annot = True)

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot
        ax[i].title  = list_of_titles[i]
        ax[i].xlabel = list_of_labels[i]
    plt.show()

# %%
#subplot_histograms(df, ['x', 'y'], ['x title', 'y title'], ['X xlabel', 'Y xlabel'])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Driving Licenses number
# - Traffic Accidents number
#
# Please plot two additional histograms that will help with your understanding of the data

# %%
# Code
fig = plt.figure(figsize=(8,3))
ax = fig.gca()
df[['driving_liceses', 'No. of Accidents']].hist(bins=10 ,ax=ax)
plt.tight_layout()
# Out:
# /Users/jadilalanazi/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fig = plt.figure(figsize=(8,3))
ax = fig.gca()
df[['No. of Casualties - Dead', 'No. of Casualties - Injured']].hist(bins=10 ,ax=ax)
plt.tight_layout()

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - Driving Licenses vs. Traffic Accidents for 2017
# - Driving Licenses vs. Traffic Accidents for 2016
# - Driving Licenses for 2016 vs 2017
# - Traffic Accidents for 2016 vs 2017
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
# Driving Licenses vs. Traffic Accidents for 2017
sns.set(style="darkgrid")
masks=df.mask(df['year']==2017)
fig = plt.figure(figsize=(7,5))
ax = fig.gca()
sns.scatterplot(data=masks ,x='driving_liceses', y='No. of Accidents',hue="region") 
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
#Driving Licenses vs. Traffic Accidents for 2016
sns.set(style="darkgrid")
masks=df.mask(df['year']==2016)
fig = plt.figure(figsize=(7,5))
ax = fig.gca()
sns.scatterplot(data=masks ,x='driving_liceses', y='No. of Accidents',hue="region") 
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
#Driving Licenses for 2016 vs 2017
sns.set(style="darkgrid")
masks111=df.mask((2015 < df['year'])&(df['year'] > 2018))
fig = plt.figure(figsize=(7,5))
ax = fig.gca()
sns.scatterplot(data=masks111 ,x='driving_liceses', y='driving_liceses',hue='region') 
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
#Traffic Accidents for 2016 vs 2017
sns.set(style="darkgrid")
masks=df.mask((2015 < df['year'])&(df['year'] > 2018))
fig = plt.figure(figsize=(7,5))
ax = fig.gca()
sns.scatterplot(data=masks ,x='No. of Accidents', y='No. of Accidents',hue="region") 
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
sns.boxplot(x = 'year', data=df)
plt.show()

# %%
# Code
n = df[['No. of Accidents','driving_liceses']]
# Plot the orbital period with horizontal boxes
sns.boxplot(data=n)
# Add in points to show each observation
sns.boxplot(data=n)

# %%
#'sns.boxplot(x = 'driving_liceses', data=df)
#plt.show()'

# %%
n = df[['No. of Casualties - Dead','No. of Casualties - Injured']]
# Plot the orbital period with horizontal boxes
sns.boxplot(data=n)
# Add in points to show each observation
sns.boxplot(data=n)
#sns.boxplot(x = 'No. of Casualties - Dead', data=df)
#plt.show()

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
fig = plt.figure(figsize=(15,8))

# 	year	region	sum
ax = fig.gca()
sns.barplot(x='region', y='driving_liceses', palette='rocket', ax=ax, data=df)

# %%
fig = plt.figure(figsize=(15,8))
ax = fig.gca()
sns.barplot(x='region', y='No. of Accidents', palette="rocket", ax=ax, data=df)

# %%
from mpl_toolkits import mplot3d
sns.set_style('whitegrid')

fig=plt.figure(figsize=(9.5,6.25))
ax=fig.add_subplot(1,1,1, projection="3d")
ax.scatter(df['No. of Accidents'],df['driving_liceses'],df['year'],c="darkblue",alpha=.5)
ax.set(xlabel='\nNo. of Accidents',ylabel='\ndriving_liceses',zlabel='\nyear');

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# - Answers:
#
# As the histofram and statistic calculations which depending on (describe function, Numpy, Panda, Scipy) show that the distribution of variables "No. of Accidents, Driving Liceses, No. of Casualties - Injured, and No. of Casualties - Dead" are positively skewed. Positively skewed data is also referred to as skewed to the right. Positive Distribution can be expressed using the following inequality:
# Mean >  Median  >  Mode
#
#
#
# - No. of Accidents:
# Mean (38225)  >  Median (16050)  >  Mode (1414)
#
# - Driving Liceses:
# Mean (28915)  >  Median (10267)  >  Mode (915)
#
# - No. of Casualties - Injured:
# Mean (2743)  >  Median (1618.)  >  Mode (374)
#
# - No. of Casualties - Dead:
# Mean (635)  >  Median (415)  >  Mode (112)
# Where the mode is the highest point of the histogram, whereas the median and mean fall to the right of it.

# %%
from scipy import stats
Mode=stats.mode(df['No. of Accidents'])
Mean=np.mean(df['No. of Accidents'].dropna())
Meadian=np.median(df['No. of Accidents'].dropna())
Varince=np.var(df['No. of Accidents'])
Stadareddiv=np.std(df['No. of Accidents'])
print(f'Mode of No. of Accidents :{Mode}')
print(f'Mean of No. of Accidents :{Mean}')
print(f'Median of No. of Accidents :{Meadian}')
print(f'Varince of No. of Accidents :{Varince}')
print(f'STD of No. of Accidents :{Stadareddiv}')
# Out:
# Mode of No. of Accidents :ModeResult(mode=array([1414.]), count=array([1]))
# Mean of No. of Accidents :38225.692307692305
# Median of No. of Accidents :16050.5
# Varince of No. of Accidents :2078523661.4437866
# STD of No. of Accidents :45590.82869880505

# %%
from scipy import stats
Mode=stats.mode(df['driving_liceses'])
Mean=np.mean(df['driving_liceses'].dropna())
Meadian=np.median(df['driving_liceses'].dropna())
Varince=np.var(df['driving_liceses'])
Stadareddiv=np.std(df['driving_liceses'])
print(f'The mode of driving_liceses :{Mode}')
print(f'The mean of driving_liceses :{Mean}')
print(f'The median of driving_liceses :{Meadian}')
print(f'Varince of driving_liceses :{Varince}')
print(f'STD of driving_liceses :{Stadareddiv}')
# Out:
# The mode of driving_liceses :ModeResult(mode=array([915]), count=array([1]))
# The mean of driving_liceses :28915.347692307692
# The median of driving_liceses :10267.0
# Varince of driving_liceses :2241648471.192955
# STD of driving_liceses :47346.05021744638

# %%
from scipy import stats
Mode=stats.mode(df['No. of Casualties - Injured'])
Mean=np.mean(df['No. of Casualties - Injured'].dropna())
Meadian=np.median(df['No. of Casualties - Injured'].dropna())
Varince=np.var(df['No. of Casualties - Injured'])
Stadareddiv=np.std(df['No. of Casualties - Injured'])
print(f'The mode of No. of Casualties - Injured :{Mode}')
print(f'The mean of No. of Casualties - Injured :{Mean}')
print(f'The median of No. of Casualties - Injured :{Meadian}')
print(f'Varince of No. of Casualties - Injured :{Varince}')
print(f'STD of No. of Casualties - Injured :{Stadareddiv}')
# Out:
# The mode of No. of Casualties - Injured :ModeResult(mode=array([374.]), count=array([1]))
# The mean of No. of Casualties - Injured :2743.0384615384614
# The median of No. of Casualties - Injured :1618.5
# Varince of No. of Casualties - Injured :8213299.190828403
# STD of No. of Casualties - Injured :2865.8854113220236

# %%
Mode=stats.mode(df['No. of Casualties - Dead'])
Mean=np.mean(df['No. of Casualties - Dead'].dropna())
Meadian=np.median(df['No. of Casualties - Dead'].dropna())
Varince=np.var(df['No. of Casualties - Dead'])
Stadareddiv=np.std(df['No. of Casualties - Dead'])
print(f'The mode of No. of Casualties - Dead :{Mode}')
print(f'The mean of No. of Casualties - Dead :{Mean}')
print(f'The median of No. of Casualties - Dead :{Meadian}')
print(f'Varince of No. of Casualties - Dead :{Varince}')
print(f'STD of No. of Casualties - Dead :{Stadareddiv}')
# Out:
# The mode of No. of Casualties - Dead :ModeResult(mode=array([112.]), count=array([1]))
# The mean of No. of Casualties - Dead :635.3846153846154
# The median of No. of Casualties - Dead :415.5
# Varince of No. of Casualties - Dead :290636.3136094675
# STD of No. of Casualties - Dead :539.1069593406002

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, we do not observe this trend.Standard deviation is influenced by outliers, one value could contribute largely to the results of the standard deviation. In that sense, the standard deviation is a good indicator of the presence of outliers. This makes standard deviation a very useful measure of spread for symmetrical distributions with no outliers.
# Generally, the more widely spread the values are, the larger the standard deviation is, the more widely spread the values are, the larger the varince is.
#
# - When **variance is large** if, for the same observation, models built on different random samples of the data will **produce very different predictions**.
# - Variance is a measure of **how *consistent* our model's predictions will be if it were fit on another sample of data**.

# %% [markdown]
# Does This Assumption Hold for:
#     - Driving Licenses
#     - Traffic Accidents
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** regions that demonstrate interesting trends in the number of driving licenses and traffic accidents. Spend some time doing outside research on provincial and central policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answer:
# According to available data and results of the statistical calculation.  Study shows that the mean of number of traffic accidents in regions of Saudi Arabia that occurred in (2016 and 2017) reached (38225) traffic accidents. The highest percentage of accidents was in Makkah (28.2%), followed by Riyadh (24.3%) and then Eastern region (18.4%).
#
# Data also showed that the mean of number of driving  licenses from (1993) to (2017) reached (28915), Makkah region came in the highest percentage in number of driving  licenses (25.9%) followed by Riyadh (23.9%), then Eastern region (22.8%).
#
# The highest number of injuried was in Makkah (32.3%), followed by Eastern  (12.6%) and Eastern Region (12.6%).
#
# Also, the highest number of injuried was in Makkah with a percent 23.5%, followed by Riyadh with 17.1%,  then the Eastern Region (12.6%).
# Based on the 2010 General Authority for Statistics data, Makkah Region is the most dense cities In KSA with a population of 6915006, followed by Riyadh with a population of 6777164, followed by Eastern  with a population of 4105780.
#
# Based on above statical analysis, it seems that there is a stronge correlation between population density  and the number of traffic accidents, the number of licenses, as well as the number of injuries and deaths caused by traffic accidents.
#
#  The higher population density, the greater number of traffic accidents, number of licenses issued, as well as the number of injuries and dead caused by traffic accidents.
#
#
# Also, Makkah Region is the hoghest number number of traffic accidents, number of licenses issued because the active commercial movement, as well as the presence of holy Masjed, and the frequent travelers of pilgrims. According to reports from Najm, the number of deaths due to traffic accidents is concentrated in the month of Ramadan, Dhul-Hijjah, Sha'ban and Shawwal.

# %%
df_new= pd.DataFrame(df.groupby('region')['No. of Accidents'].sum())
def percentage(part):
   whole= df_new['No. of Accidents'].sum()
   percentage= 100 * part/whole
   p=percentage.round(1)
   return p,'%'
df_new['.P.C']= df_new['No. of Accidents'].apply(lambda x : percentage(x))
df_new
# Out:
#                   No. of Accidents       .P.C
# region
# Al-Baha                     5032.0   (0.5, %)
# Al-Jouf                    20681.0   (2.1, %)
# Al-Qaseem                  48069.0   (4.8, %)
# Assir                      57929.0   (5.8, %)
# Eastern                   183052.0  (18.4, %)
# Hail                       19578.0   (2.0, %)
# Jazan                      48034.0   (4.8, %)
# Madinah                    30545.0   (3.1, %)
# Makkah                    280379.0  (28.2, %)
# Najran                      6428.0   (0.6, %)
# Northern Boarder           24736.0   (2.5, %)
# Riyadh                    241661.0  (24.3, %)
# Tabouk                     27744.0   (2.8, %)

# %%
df_new= pd.DataFrame(df.groupby('region')['driving_liceses'].sum())
def percentage(part):
   whole= df_new['driving_liceses'].sum()
   percentage= 100 * part/whole
   p=percentage.round(1)
   return p,'%'
df_new['.P.C']= df_new['driving_liceses'].apply(lambda x : percentage(x))

df_new
# Out:
#                   driving_liceses       .P.C
# region
# Al-Baha                    117051   (1.2, %)
# Al-Jouf                    164652   (1.8, %)
# Al-Qaseem                  562292   (6.0, %)
# Assir                      490615   (5.2, %)
# Eastern                   2147243  (22.8, %)
# Hail                       257782   (2.7, %)
# Jazan                      214066   (2.3, %)
# Madinah                    349084   (3.7, %)
# Makkah                    2433659  (25.9, %)
# Najran                     141494   (1.5, %)
# Northern Boarder            72397   (0.8, %)
# Riyadh                    2243304  (23.9, %)
# Tabouk                     203849   (2.2, %)

# %%
df_new= pd.DataFrame(df.groupby('region')['No. of Casualties - Dead'].sum())
def percentage(part):
   whole= df_new['No. of Casualties - Dead'].sum()
   percentage= 100 * part/whole
   p=percentage.round(1)
   return p,'%'
df_new['.P.C']= df_new['No. of Casualties - Dead'].apply(lambda x : percentage(x))

df_new
# Out:
#                   No. of Casualties - Dead       .P.C
# region
# Al-Baha                              319.0   (1.9, %)
# Al-Jouf                              485.0   (2.9, %)
# Al-Qaseem                            716.0   (4.3, %)
# Assir                               1811.0  (11.0, %)
# Eastern                             2076.0  (12.6, %)
# Hail                                 564.0   (3.4, %)
# Jazan                                980.0   (5.9, %)
# Madinah                             1402.0   (8.5, %)
# Makkah                              3884.0  (23.5, %)
# Najran                               367.0   (2.2, %)
# Northern Boarder                     305.0   (1.8, %)
# Riyadh                              2829.0  (17.1, %)
# Tabouk                               782.0   (4.7, %)

# %%
df_new= pd.DataFrame(df.groupby('region')['No. of Casualties - Injured'].sum())
def percentage(part):
   whole= df_new['No. of Casualties - Injured'].sum()
   percentage= 100 * part/whole
   p=percentage.round(1)
   return p,'%'
df_new['.P.C']= df_new['No. of Casualties - Injured'].apply(lambda x : percentage(x))

df_new
# Out:
#                   No. of Casualties - Injured       .P.C
# region
# Al-Baha                                2234.0   (3.1, %)
# Al-Jouf                                1782.0   (2.5, %)
# Al-Qaseem                              2959.0   (4.1, %)
# Assir                                  4909.0   (6.9, %)
# Eastern                                8966.0  (12.6, %)
# Hail                                   1705.0   (2.4, %)
# Jazan                                  4466.0   (6.3, %)
# Madinah                                7101.0  (10.0, %)
# Makkah                                23006.0  (32.3, %)
# Najran                                 1472.0   (2.1, %)
# Northern Boarder                       1005.0   (1.4, %)
# Riyadh                                 8747.0  (12.3, %)
# Tabouk                                 2967.0   (4.2, %)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# - Based on your exploration of the data, what are you key takeaways and recommendations?
# - Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:
#
# Althogh the data which were given is a valuable and usefel, we still need more data In order to make this study more valuable and relyable, we may  need the follweing data:
# 1. The accurate traffic accedent location: Inside the city, outside the city, street name or intersection
# 2. The accurate traffic accedent date: day, month and year
# 3. Type of incident
# Such as collision between opposite vehicles (face to face), angle-shaped collision (collision between cars at intersections), rear collision (cars moving in the same direction), side collision, collision during rotation (rolling), collision of a parked vehicle, fixed body impact , Accident for one car (usually a coup or loss of control of the car), run over pedestrians, rammed a bicycle, rammed an animal
# 4. Causes of traffic accidents or factors leading to traffic accidents
# Such as  non-compliance with traffic regulations, reckless driving, non-maintenance or inspection of the vehicle (road), road conditions (road work, dangerous curves, lack of safety factors, weather conditions: rain, fog , Sand, overclocking, lack of driver efficiency, lack of efficiency and equipment of transport (vehicle), traffic offense, lack of attention and concentration from the driver, driving in inappropriate climatic conditions, driving in turbulent psychological conditions, irregular stopping, irregular overflow -The driver under the influence of heady or anesthetic
# 5. Age, nationality and sex of the driver
#
#
#
# Finally, based on provided data and outside reserch, I have provided some recommendations that may help to reduce the problem of traffic accidents and its side effects:
# 1. spread traffic culture in the community by providing some road safety programs to reduce road traffic accedents
# 2. Tightening penalties for traffic violations
# 3. Raising the efficiency of transport infrastructure by reducing delay of  implementation of projects in basic road and highways
# 4. make public transport an attractive option
# Understand existing service quality to inform upgrade decisions
# The core consideration for analysis are:
# in demand travel routes (including journeys currently taken by car).
# existing service frequency.
# existing service capacity.
# journey speeds.
# 5. Improve road safety and performance
#
#
# A  study published in a journal conducted by researchers from King Abdullah International Medical Research Center revealed that there is a relationship between the implementation of Sahir system and reducing the rate of injuries and deaths related to traffic accidents, where it was found that Sahir system achieved a 20% decrease in the severity of injury and (37.8%) In deaths resulting from traffic accidents of the injured who are received at the emergency department at King Fahd Hospital, King Abdulaziz Medical City, Ministry of National Guard
